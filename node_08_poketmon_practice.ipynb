# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import os
csv_path = "./Pokemon.csv"
original_data = pd.read_csv(csv_path)

# %%
pokemon = original_data.copy()
print(pokemon.shape)
pokemon.head()
# Out:
# (800, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
legendary = pokemon[pokemon["Legendary"] == True].reset_index(drop=True)
ordinary = pokemon[pokemon["Legendary"] == False].reset_index(drop=True)

# %%
value_count = pokemon["#"].value_counts()
filtered_values = value_count[value_count > 1]
filtered_values
# Out:
# #
# 479    6
# 386    4
# 710    4
# 711    4
# 646    3
#       ..
# 382    2
# 373    2
# 18     2
# 15     2
# 681    2
# Name: count, Length: 65, dtype: int64

# %%
filtered_df = pokemon[pokemon["#"].isin(filtered_values.index)].sort_values(by="#", ascending=False)
filtered_df
# Out:
#        #                       Name   Type 1  Type 2  Total  HP  Attack  \
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 786  711        GourgeistLarge Size    Ghost   Grass    494  75      95
# ..   ...                        ...      ...     ...    ...  ..     ...
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# 6      6                  Charizard     Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 3      3      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 2      3                   Venusaur    Grass  Poison    525  80      82
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon.loc[pokemon["#"].isin(filtered_values.index), ["#", "Name"]]
# Out:
#        #                       Name
# 2      3                   Venusaur
# 3      3      VenusaurMega Venusaur
# 6      6                  Charizard
# 7      6  CharizardMega Charizard X
# 8      6  CharizardMega Charizard Y
# ..   ...                        ...
# 787  711        GourgeistSuper Size
# 795  719                    Diancie
# 796  719        DiancieMega Diancie
# 797  720        HoopaHoopa Confined
# 798  720         HoopaHoopa Unbound
#
# [144 rows x 2 columns]

# %%
type1 = set(pokemon["Type 1"])
type2 = set(pokemon["Type 2"])

# %%
type1.difference(type2)
# Out:
# set()

# %%
set(pokemon["Type 2"]).difference(set(pokemon["Type 1"]))
# Out:
# {nan}

# %%
legendary["name_count"] = legendary["Name"].apply(lambda i: len(i))    
legendary.head()
# Out:
#      #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  144             Articuno       Ice    Flying    580   90      85      100
# 1  145               Zapdos  Electric    Flying    580   90      90       85
# 2  146              Moltres      Fire    Flying    580   90     100       90
# 3  150               Mewtwo   Psychic       NaN    680  106     110       90
# 4  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       95      125     85           1       True           8
# 1      125       90    100           1       True           6
# 2      125       85     90           1       True           7
# 3      154       90    130           1       True           6
# 4      154      100    130           1       True          19

# %%
ordinary["name_count"] = ordinary["Name"].apply(lambda i: len(i))    
ordinary.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       65       65     45           1      False           9
# 1       80       80     60           1      False           7
# 2      100      100     80           1      False           8
# 3      122      120     80           1      False          21
# 4       60       50     65           1      False          10

# %%
pokemon["name_count"] = pokemon["Name"].apply(lambda i: len(i))
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count
# 0       65       65     45           1      False           9
# 1       80       80     60           1      False           7
# 2      100      100     80           1      False           8
# 3      122      120     80           1      False          21
# 4       60       50     65           1      False          10

# %%
pokemon["long_name"] = pokemon["name_count"] >= 10
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name
# 0       65       65     45           1      False           9      False
# 1       80       80     60           1      False           7      False
# 2      100      100     80           1      False           8      False
# 3      122      120     80           1      False          21       True
# 4       60       50     65           1      False          10       True

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 795      100      150     50           6       True           7      False
# 796      160      110    110           6       True          19       True
# 797      150      130     70           6       True          19       True
# 798      170      130     80           6       True          18       True
# 799      130       90     70           6       True           9      False
#
#            Name_nospace
# 795             Diancie
# ...

# %%
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 0       65       65     45           1      False           9      False
# 1       80       80     60           1      False           7      False
# 2      100      100     80           1      False           8      False
# 3      122      120     80           1      False          21       True
# 4       60       50     65           1      False          10       True
#
#            Name_nospace  name_isalpha
# 0             Bulbasaur          True
# ...

# %%
pokemon[pokemon["name_isalpha"] == False]
# Out:
#        #           Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 34    29      Nidoran X   Poison     NaN    275   55      47       52
# 37    32      Nidoran Y   Poison     NaN    273   46      57       40
# 90    83      Farfetchd   Normal  Flying    352   52      65       55
# 131  122        Mr Mime  Psychic   Fairy    460   40      45       65
# 252  233        Porygon   Normal     NaN    515   85      80       90
# 270  250          Ho Oh     Fire  Flying    680  106     130       90
# 487  439        Mime Jr  Psychic   Fairy    310   20      25       45
# 525  474      Porygon Z   Normal     NaN    535   85      80       70
# 794  718  Zygarde Forme   Dragon  Ground    600  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name  \
# 34        40       40     41           1      False           8      False
# 37        40       40     50           1      False           8      False
# ...

# %%
pokemon = pokemon.replace(to_replace="Nidoran♀", value="Nidoran X")
pokemon = pokemon.replace(to_replace="Nidoran♂", value="Nidoran Y")
pokemon = pokemon.replace(to_replace="Farfetch'd", value="Farfetchd")
pokemon = pokemon.replace(to_replace="Mr. Mime", value="Mr Mime")
pokemon = pokemon.replace(to_replace="Porygon2", value="Porygon")
pokemon = pokemon.replace(to_replace="Ho-oh", value="Ho Oh")
pokemon = pokemon.replace(to_replace="Mime Jr.", value="Mime Jr")
pokemon = pokemon.replace(to_replace="Porygon-Z", value="Porygon Z")
pokemon = pokemon.replace(to_replace="Zygarde50% Forme", value="Zygarde Forme")

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())
pokemon[pokemon["name_isalpha"] == False]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, name_count, long_name, Name_nospace, name_isalpha]
# Index: []

# %%
import re

def tokenize(name):

    name_split = name.split(" ")
    tokens = []
    for name_part in name_split:
        name_re = re.findall('[A-Z][a-z]*', name_part)
        print(name_re)
        tokens.extend(name_re)
    return np.array(tokens)

# %%
tokenize("HoopaHoopa")
# Out:
# ['Hoopa', 'Hoopa']
# array(['Hoopa', 'Hoopa'], dtype='<U5')

# %%
all_tokens = list(legendary["Name"].apply(tokenize).values)
all_tokens[:5]
# Out:
# [array(['Articuno'], dtype='<U8'),
#  array(['Zapdos'], dtype='<U6'),
#  array(['Moltres'], dtype='<U7'),
#  array(['Mewtwo'], dtype='<U6'),
#  array(['Mewtwo', 'Mega', 'Mewtwo', 'X'], dtype='<U6')]

# %%
all_tokens = list(legendary["Name"].apply(tokenize).values)

token_set = []
for token in all_tokens:
    token_set.extend(token)

token_set_sort = sorted(set(token_set))
print(len(token_set_sort))
print(token_set_sort)
# Out:
# 65
# ['Altered', 'Arceus', 'Articuno', 'Attack', 'Azelf', 'Black', 'Cobalion', 'Confined', 'Darkrai', 'Defense', 'Deoxys', 'Dialga', 'Diancie', 'Entei', 'Forme', 'Giratina', 'Groudon', 'Heatran', 'Ho', 'Hoopa', 'Incarnate', 'Jirachi', 'Kyogre', 'Kyurem', 'Land', 'Landorus', 'Latias', 'Latios', 'Lugia', 'Mega', 'Mesprit', 'Mewtwo', 'Moltres', 'Normal', 'Origin', 'Palkia', 'Primal', 'Raikou', 'Rayquaza', 'Regice', 'Regigigas', 'Regirock', 'Registeel', 'Reshiram', 'Shaymin', 'Sky', 'Speed', 'Suicune', 'Terrakion', 'Therian', 'Thundurus', 'Tornadus', 'Unbound', 'Uxie', 'Victini', 'Virizion', 'Volcanion', 'White', 'X', 'Xerneas', 'Y', 'Yveltal', 'Zapdos', 'Zekrom', 'Zygarde']

# %%
from collections import Counter

most_common = Counter(token_set).most_common(10)
most_common
# Out:
# [('Forme', 15),
#  ('Mega', 6),
#  ('Mewtwo', 5),
#  ('Kyurem', 5),
#  ('Deoxys', 4),
#  ('Hoopa', 4),
#  ('Latias', 3),
#  ('Latios', 3),
#  ('Kyogre', 3),
#  ('Groudon', 3)]

# %%
for token, _ in most_common:
    pokemon[f"{token}"] = pokemon["Name"].str.contains(token)

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  ...  Forme   Mega  Mewtwo  Kyurem  Deoxys  Hoopa  Latias  \
# ...

# %%
types = list(set(pokemon["Type 1"]))

# %%
for t in types:
    pokemon[t] = (pokemon["Type 1"] == t) | (pokemon["Type 2"] == t)
    
pokemon[[["Type 1", "Type 2"] + types][0]].head()
# Out:
#   Type 1  Type 2  Fighting   Fire   Dark  Grass  Water  Ghost  Fairy  \
# 0  Grass  Poison     False  False  False   True  False  False  False
# 1  Grass  Poison     False  False  False   True  False  False  False
# 2  Grass  Poison     False  False  False   True  False  False  False
# 3  Grass  Poison     False  False  False   True  False  False  False
# 4   Fire     NaN     False   True  False  False  False  False  False
#
#    Electric   Rock  Normal  Psychic  Poison    Ice  Dragon  Ground  Steel  \
# 0     False  False   False    False    True  False   False   False  False
# 1     False  False   False    False    True  False   False   False  False
# 2     False  False   False    False    True  False   False   False  False
# 3     False  False   False    False    True  False   False   False  False
# 4     False  False   False    False   False  False   False   False  False
#
#    Flying    Bug
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# ...

# %% [markdown]
# ## name tokens

# %%
pkm = original_data.copy()

# %%
lgd_name_list = list(set(pkm.loc[pkm["Legendary"] == True, "Name"]))
lgd_name = pd.DataFrame(lgd_name_list, columns=["Name"])

# %%
lgd_all_tokens = list(lgd_name["Name"].apply(tokenize).values)

lgd_token_set = []
for token in lgd_all_tokens:
    lgd_token_set.extend(token)

lgd_token_set_sort = sorted(set(lgd_token_set))
print(len(lgd_token_set_sort))
print(lgd_token_set_sort)
# Out:
# 65
# ['Altered', 'Arceus', 'Articuno', 'Attack', 'Azelf', 'Black', 'Cobalion', 'Confined', 'Darkrai', 'Defense', 'Deoxys', 'Dialga', 'Diancie', 'Entei', 'Forme', 'Giratina', 'Groudon', 'Heatran', 'Ho', 'Hoopa', 'Incarnate', 'Jirachi', 'Kyogre', 'Kyurem', 'Land', 'Landorus', 'Latias', 'Latios', 'Lugia', 'Mega', 'Mesprit', 'Mewtwo', 'Moltres', 'Normal', 'Origin', 'Palkia', 'Primal', 'Raikou', 'Rayquaza', 'Regice', 'Regigigas', 'Regirock', 'Registeel', 'Reshiram', 'Shaymin', 'Sky', 'Speed', 'Suicune', 'Terrakion', 'Therian', 'Thundurus', 'Tornadus', 'Unbound', 'Uxie', 'Victini', 'Virizion', 'Volcanion', 'White', 'X', 'Xerneas', 'Y', 'Yveltal', 'Zapdos', 'Zekrom', 'Zygarde']

# %%
Counter(lgd_token_set).most_common(10)
# Out:
# [('Forme', 15),
#  ('Mega', 6),
#  ('Kyurem', 5),
#  ('Mewtwo', 5),
#  ('Hoopa', 4),
#  ('Deoxys', 4),
#  ('Rayquaza', 3),
#  ('Incarnate', 3),
#  ('Latios', 3),
#  ('Therian', 3)]
